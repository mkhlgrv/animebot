# %%
import requests
from scrapy.selector import Selector
import re
import os
from dotenv import load_dotenv
import telegram
import time 
from functools import wraps
load_dotenv()
import os
token = os.getenv('token')
chat_id = os.getenv('chat_id')
user_agent = os.getenv('user_agent')
from log import logger

# %%
def timeit(func):
    @wraps(func)
    def timeit_wrapper(*args, **kwargs):
        start_time = time.perf_counter()
        result = func(*args, **kwargs)
        end_time = time.perf_counter()
        total_time = end_time - start_time
        print(f'Function {func.__name__}{args} {kwargs} Took {total_time:.4f} seconds')
        return result
    return timeit_wrapper

# %%
# список аниме

# %%
def get_series_cnt(content:Selector)->tuple:
    text = "".join(content.xpath("./text()").getall())
    series_match= re.search(r"(\d+)\sсери", text)
    ses_match= re.search(r"(\d+)\sсез", text)
    films_match = re.search(r"(\d+)\sфильм", text)
    
    series_cnt = int(series_match.group(1)) if series_match else 0
    films_cnt = int(films_match.group(1)) if films_match else 0
    return series_cnt, films_cnt
    
#series_cnts = [get_series_cnt_updated(item) for item in x_series]

# %%
#Selection
#selected = ['/full-metal-alchemist/']
# selected_dict = {key:item for key, item in anime_dict.items() if key in selected}

# %%
class EmptyPageException(Exception):
    """Raises when page is empty"""
    pass

# %%
# class LoggerTimeit(Logger):
#     self.start_time = ...
#     self.end_time = ...

# %%
# @timeit
def get_data(url:str)->tuple:
    """The function gets url to scrape site content specifically title name,title page source, count of series,count of films'
    from all content pages of site and return dict object
    INPUT:
    URL:url adress must be like https://jut.su/anime/page-(\d)/
    Note: It's also use global constants from .env file  
    
    OUTPUT:
    dict: the dict object which kind is {title_internal_link:
    {'title_internal_link':title internal link,
     'title': title name in Russian,
     'series_cnt': series count,
     'film_cnt': film count
      }}"""
    logger.info("Starts session")
    anime_dict = {}
    page_num = 1
    status = 1
    while status == 1:
        try:
            logger.info(f"Page {page_num}")
            page_url = url + f"page-{page_num}/"
            response = requests.get(page_url,headers={
            "User-Agent": user_agent # global var
                    })
            content = response.content.decode("cp1251").encode('utf-8')

            selections = Selector(text=content).xpath('//div[contains(@class, "all_anime_global")]')
            links = selections.xpath('./a/@href').getall()
            titles_name = selections.xpath('.//div[contains(@class, "aaname")]/text()').getall()

            if len(titles_name)==0:
                raise EmptyPageException
            
            titles_info = selections.xpath('.//div[contains(@class, "aailines")]')
            series_cnts = [get_series_cnt(item) for item in titles_info]
            
            for link, title, (series_cnt, films_cnt) in zip(links,titles_name,series_cnts):
                 if link not in anime_dict:
                        anime_dict[link] = {"ref":link
                                            , "title":title
                                            , "series_cnt":series_cnt
                                            ,'films_cnt':films_cnt}       
            
            page_num += 1
        
        except EmptyPageException:
            status = 0
        except Exception as e:
            status = -1
            logger.error(e)
            
    logger.info(f"Ends session with status={status}")
    return status, anime_dict

# %%
status, anim_dict = get_data("https://jut.su/anime/sajkn")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378                 # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16304/3314834314.py in <module>
# ----> 1 status, anim_dict = get_data("https://jut.su/anime/sajkn")
#
# ~\AppData\Local\Temp/ipykernel_16304/958555650.py in get_data(url)
#      22             logger.info(f"Page {page_num}")
#      23             page_url = url + f"page-{page_num}/"
# ---> 24             response = requests.get(page_url,headers={
#      25             "User-Agent": user_agent # global var
#      26                     })
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in <listcomp>(.0)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     235             else:
#     236
# --> 237                 resp = self.send(
#     238                     req,
#     239                     stream=stream,
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598
#     599             # Make the request on the httplib connection object.
# --> 600             httplib_response = self._make_request(conn, method, url,
#     601                                                   timeout=timeout_obj,
#     602                                                   body=body, headers=headers,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381                 # Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
anim_dict
# Out:
# {'/shingekii-no-kyojin/': {'ref': '/shingekii-no-kyojin/',
#   'title': 'Атака титанов',
#   'series_cnt': 87,
#   'films_cnt': 2},
#  '/full-metal-alchemist/': {'ref': '/full-metal-alchemist/',
#   'title': 'Стальной алхимик',
#   'series_cnt': 115,
#   'films_cnt': 2},
#  '/onepunchman/': {'ref': '/onepunchman/',
#   'title': 'Ванпанчмен',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/sword-arts-online/': {'ref': '/sword-arts-online/',
#   'title': 'Мастера меча онлайн',
#   'series_cnt': 96,
#   'films_cnt': 2},
#  '/boku-hero-academia/': {'ref': '/boku-hero-academia/',
#   'title': 'Моя геройская академия',
#   'series_cnt': 118,
#   'films_cnt': 3},
#  '/kimetsu-yaiba/': {'ref': '/kimetsu-yaiba/',
#   'title': 'Клинок, рассекающий демонов',
#   'series_cnt': 44,
#   'films_cnt': 0},
#  '/tokushu/': {'ref': '/tokushu/',
#   'title': 'Токийский Гуль',
#   'series_cnt': 48,
#   'films_cnt': 0},
#  '/hunter-hunter/': {'ref': '/hunter-hunter/',
#   'title': 'Хантер х Хантер',
#   'series_cnt': 148,
#   'films_cnt': 2},
#  '/stein-gate/': {'ref': '/stein-gate/',
#   'title': 'Врата Штейна',
#   'series_cnt': 49,
#   'films_cnt': 1},
#  '/life-no-game/': {'ref': '/life-no-game/',
#   'title': 'Нет игры - нет жизни',
#   'series_cnt': 12,
#   'films_cnt': 1},
#  '/code-geass/': {'ref': '/code-geass/',
#   'title': 'Код Гиас',
#   'series_cnt': 50,
#   'films_cnt': 6},
#  '/toradora/': {'ref': '/toradora/',
#   'title': 'ТораДора',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/jujutsu-kaisen/': {'ref': '/jujutsu-kaisen/',
#   'title': 'Магическая битва',
#   'series_cnt': 24,
#   'films_cnt': 1},
#  '/oneepiece/': {'ref': '/oneepiece/',
#   'title': 'Ван Пис',
#   'series_cnt': 1038,
#   'films_cnt': 12},
#  '/noragaami/': {'ref': '/noragaami/',
#   'title': 'Бездомный Бог',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/re-zerou-kara/': {'ref': '/re-zerou-kara/',
#   'title': 'С нуля: Пособие по выживанию в альтернативном мире',
#   'series_cnt': 50,
#   'films_cnt': 2},
#  '/angela-beats/': {'ref': '/angela-beats/',
#   'title': 'Ангельские ритмы!',
#   'series_cnt': 14,
#   'films_cnt': 0},
#  '/akaame-ga-kill/': {'ref': '/akaame-ga-kill/',
#   'title': 'Убийца Акаме!',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/boku-dake/': {'ref': '/boku-dake/',
#   'title': 'Город, в котором меня нет',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/nanatsu-taizai/': {'ref': '/nanatsu-taizai/',
#   'title': 'Семь смертных грехов',
#   'series_cnt': 96,
#   'films_cnt': 0},
#  '/mirai-nikki/': {'ref': '/mirai-nikki/',
#   'title': 'Дневник будущего',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/mob-100/': {'ref': '/mob-100/',
#   'title': 'Моб Психо 100',
#   'series_cnt': 30,
#   'films_cnt': 0},
#  '/roomination/': {'ref': '/roomination/',
#   'title': 'Класс убийц',
#   'series_cnt': 47,
#   'films_cnt': 0},
#  '/ao-exorcist/': {'ref': '/ao-exorcist/',
#   'title': 'Синий Экзорцист',
#   'series_cnt': 38,
#   'films_cnt': 1},
#  '/haaikyu/': {'ref': '/haaikyu/',
#   'title': 'Волейбол!',
#   'series_cnt': 85,
#   'films_cnt': 2},
#  '/yakusoku-neverland/': {'ref': '/yakusoku-neverland/',
#   'title': 'Обещанный Неверленд',
#   'series_cnt': 23,
#   'films_cnt': 0},
#  '/kono-subarashii/': {'ref': '/kono-subarashii/',
#   'title': 'Этот прекрасный мир',
#   'series_cnt': 22,
#   'films_cnt': 1},
#  '/bleeach/': {'ref': '/bleeach/',
#   'title': 'Блич',
#   'series_cnt': 370,
#   'films_cnt': 4},
#  '/kiseijuu/': {'ref': '/kiseijuu/',
#   'title': 'Паразит',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/cowboy-bebop/': {'ref': '/cowboy-bebop/',
#   'title': 'Ковбой Бибоп',
#   'series_cnt': 26,
#   'films_cnt': 1},
#  '/neon-evangelion/': {'ref': '/neon-evangelion/',
#   'title': 'Евангелион',
#   'series_cnt': 26,
#   'films_cnt': 1},
#  '/faairytail/': {'ref': '/faairytail/',
#   'title': 'Фейри Тейл',
#   'series_cnt': 328,
#   'films_cnt': 2},
#  '/death-parade/': {'ref': '/death-parade/',
#   'title': 'Парад смерти',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/vioulet-evergarden/': {'ref': '/vioulet-evergarden/',
#   'title': 'Вайолет Эвергарден',
#   'series_cnt': 14,
#   'films_cnt': 0},
#  '/another/': {'ref': '/another/',
#   'title': 'Другая',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/seishun-buta/': {'ref': '/seishun-buta/',
#   'title': 'Этот глупый свин не понимает мечту девочки-зайки',
#   'series_cnt': 13,
#   'films_cnt': 1},
#  '/shokugeki-no-souma/': {'ref': '/shokugeki-no-souma/',
#   'title': 'Повар-боец Сома',
#   'series_cnt': 86,
#   'films_cnt': 0},
#  '/dr-stoune/': {'ref': '/dr-stoune/',
#   'title': 'Доктор Стоун',
#   'series_cnt': 36,
#   'films_cnt': 0},
#  '/kaguya-sama/': {'ref': '/kaguya-sama/',
#   'title': 'Госпожа Кагуя: в любви как на войне',
#   'series_cnt': 37,
#   'films_cnt': 0},
#  '/psycho-pass/': {'ref': '/psycho-pass/',
#   'title': 'Психопаспорт',
#   'series_cnt': 41,
#   'films_cnt': 1},
#  '/soul-eater/': {'ref': '/soul-eater/',
#   'title': 'Пожиратель душ',
#   'series_cnt': 51,
#   'films_cnt': 0},
#  '/mada-shiranai/': {'ref': '/mada-shiranai/',
#   'title': 'Невиданный цветок',
#   'series_cnt': 11,
#   'films_cnt': 1},
#  '/gurren-lagan/': {'ref': '/gurren-lagan/',
#   'title': 'Гуррен-Лаганн',
#   'series_cnt': 27,
#   'films_cnt': 2},
#  '/darling-in-the-franxx/': {'ref': '/darling-in-the-franxx/',
#   'title': 'Милый во Франксе',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/jojo-bizarre-adventure/': {'ref': '/jojo-bizarre-adventure/',
#   'title': 'Невероятные приключения ДжоДжо',
#   'series_cnt': 176,
#   'films_cnt': 0},
#  '/hataraku-maou-sama/': {'ref': '/hataraku-maou-sama/',
#   'title': 'Сатана на подработке!',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/black-clouver/': {'ref': '/black-clouver/',
#   'title': 'Чёрный клевер',
#   'series_cnt': 170,
#   'films_cnt': 0},
#  '/overlord/': {'ref': '/overlord/',
#   'title': 'Повелитель',
#   'series_cnt': 52,
#   'films_cnt': 0},
#  '/tate-yuusha-nariagari/': {'ref': '/tate-yuusha-nariagari/',
#   'title': 'Восхождение героя щита',
#   'series_cnt': 38,
#   'films_cnt': 0},
#  '/danmachi/': {'ref': '/danmachi/',
#   'title': 'Может, я встречу тебя в подземелье?',
#   'series_cnt': 60,
#   'films_cnt': 0},
#  '/fate-zer-o/': {'ref': '/fate-zer-o/',
#   'title': 'Судьба: Начало',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/kakeguruui/': {'ref': '/kakeguruui/',
#   'title': 'Безумный азарт',
#   'series_cnt': 30,
#   'films_cnt': 0},
#  '/clanad/': {'ref': '/clanad/',
#   'title': 'Кланнад',
#   'series_cnt': 49,
#   'films_cnt': 1},
#  '/durara/': {'ref': '/durara/',
#   'title': 'Дюрарара!!',
#   'series_cnt': 62,
#   'films_cnt': 0},
#  '/monogatari-series/': {'ref': '/monogatari-series/',
#   'title': 'Цикл историй',
#   'series_cnt': 87,
#   'films_cnt': 4},
#  '/yahari-ore-no-seishun/': {'ref': '/yahari-ore-no-seishun/',
#   'title': 'Розовая пора моей школьной жизни сплошной обман',
#   'series_cnt': 40,
#   'films_cnt': 0},
#  '/hyouka/': {'ref': '/hyouka/',
#   'title': 'Хьёка',
#   'series_cnt': 22,
#   'films_cnt': 0},
#  '/chuunibyou-demo/': {'ref': '/chuunibyou-demo/',
#   'title': 'Чудачества любви не помеха',
#   'series_cnt': 24,
#   'films_cnt': 2},
#  '/slime-datta-ken/': {'ref': '/slime-datta-ken/',
#   'title': 'О моём перерождении в слизь',
#   'series_cnt': 49,
#   'films_cnt': 0},
#  '/owari-no-seraph/': {'ref': '/owari-no-seraph/',
#   'title': 'Последний Серафим',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/made-abyss/': {'ref': '/made-abyss/',
#   'title': 'Сделано в Бездне',
#   'series_cnt': 25,
#   'films_cnt': 1},
#  '/bungo-stray-dogs/': {'ref': '/bungo-stray-dogs/',
#   'title': 'Бродячие псы: Литературные гении',
#   'series_cnt': 36,
#   'films_cnt': 0},
#  '/vinland-saga/': {'ref': '/vinland-saga/',
#   'title': 'Сага о Винланде',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/madoka-magica/': {'ref': '/madoka-magica/',
#   'title': 'Волшебница Мадока Магика',
#   'series_cnt': 37,
#   'films_cnt': 3},
#  '/pet-na-kanojo/': {'ref': '/pet-na-kanojo/',
#   'title': 'Кошечка из Сакурасо',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/deadman-wonderland/': {'ref': '/deadman-wonderland/',
#   'title': 'Страна чудес смертников',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/enen-no-shouboutai/': {'ref': '/enen-no-shouboutai/',
#   'title': 'Пламенная бригада пожарных',
#   'series_cnt': 48,
#   'films_cnt': 0},
#  '/kaichou-wa-maid/': {'ref': '/kaichou-wa-maid/',
#   'title': 'Президент - горничная!',
#   'series_cnt': 27,
#   'films_cnt': 0},
#  '/guilty-crown/': {'ref': '/guilty-crown/',
#   'title': 'Корона Грешника',
#   'series_cnt': 22,
#   'films_cnt': 0},
#  '/samurai-champlo/': {'ref': '/samurai-champlo/',
#   'title': 'Самурай Чамплу',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/dragonball/': {'ref': '/dragonball/',
#   'title': 'Драгонболл',
#   'series_cnt': 798,
#   'films_cnt': 16},
#  '/kobayashi/': {'ref': '/kobayashi/',
#   'title': 'Дракон-горничная Кобаяши',
#   'series_cnt': 27,
#   'films_cnt': 0},
#  '/horimiya/': {'ref': '/horimiya/',
#   'title': 'Хоримия',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/kuroko-no-basuke/': {'ref': '/kuroko-no-basuke/',
#   'title': 'Баскетбол Куроко',
#   'series_cnt': 76,
#   'films_cnt': 4},
#  '/kuroshitsuuji/': {'ref': '/kuroshitsuuji/',
#   'title': 'Темный дворецкий',
#   'series_cnt': 46,
#   'films_cnt': 1},
#  '/nisekooi/': {'ref': '/nisekooi/',
#   'title': 'Притворная любовь',
#   'series_cnt': 32,
#   'films_cnt': 0},
#  '/spy-family/': {'ref': '/spy-family/',
#   'title': 'Семья шпиона',
#   'series_cnt': 17,
#   'films_cnt': 0},
#  '/kyoukai-kanata/': {'ref': '/kyoukai-kanata/',
#   'title': 'За гранью',
#   'series_cnt': 13,
#   'films_cnt': 1},
#  '/douroro/': {'ref': '/douroro/',
#   'title': 'Дороро',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/zankyou-no-terror/': {'ref': '/zankyou-no-terror/',
#   'title': 'Эхо террора',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/login-horizon/': {'ref': '/login-horizon/',
#   'title': 'Логин Горизонт',
#   'series_cnt': 62,
#   'films_cnt': 0},
#  '/shugi-no-kyoushitsu/': {'ref': '/shugi-no-kyoushitsu/',
#   'title': 'Класс превосходства',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/host-club/': {'ref': '/host-club/',
#   'title': 'Хост-клуб Оранской школы',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/tokyo-reveengers/': {'ref': '/tokyo-reveengers/',
#   'title': 'Токийские мстители',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/mushoku-tensei/': {'ref': '/mushoku-tensei/',
#   'title': 'Реинкарнация безработного',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/kaibutsu-kun/': {'ref': '/kaibutsu-kun/',
#   'title': 'Монстр за соседней партой',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/goblin-slayer/': {'ref': '/goblin-slayer/',
#   'title': 'Убийца гоблинов',
#   'series_cnt': 12,
#   'films_cnt': 1},
#  '/unlimited-blade-works/': {'ref': '/unlimited-blade-works/',
#   'title': 'Клинков бесконечный край',
#   'series_cnt': 26,
#   'films_cnt': 1},
#  '/mahouka-koukou-no-rettousei/': {'ref': '/mahouka-koukou-no-rettousei/',
#   'title': 'Непутёвый ученик в школе магии',
#   'series_cnt': 40,
#   'films_cnt': 1},
#  '/k-on/': {'ref': '/k-on/',
#   'title': 'К-он!',
#   'series_cnt': 41,
#   'films_cnt': 1},
#  '/gintamas/': {'ref': '/gintamas/',
#   'title': 'Гинтама',
#   'series_cnt': 367,
#   'films_cnt': 2},
#  '/saiki-kusuo/': {'ref': '/saiki-kusuo/',
#   'title': 'Ох уж этот экстрасенс Сайки Кусуо!',
#   'series_cnt': 56,
#   'films_cnt': 0},
#  '/magi/': {'ref': '/magi/',
#   'title': 'Маги: Лабиринт волшебства',
#   'series_cnt': 63,
#   'films_cnt': 0},
#  '/date-o-live/': {'ref': '/date-o-live/',
#   'title': 'Рандеву с жизнью',
#   'series_cnt': 47,
#   'films_cnt': 1},
#  '/reelife/': {'ref': '/reelife/',
#   'title': 'Повторная жизнь',
#   'series_cnt': 17,
#   'films_cnt': 0},
#  '/gold-time/': {'ref': '/gold-time/',
#   'title': 'Золотая пора',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/black-lagoon/': {'ref': '/black-lagoon/',
#   'title': 'Пираты черной лагуны',
#   'series_cnt': 29,
#   'films_cnt': 0},
#  '/fate-night/': {'ref': '/fate-night/',
#   'title': 'Судьба: Ночь схватки',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/danganronpa/': {'ref': '/danganronpa/',
#   'title': 'Данганронпа: школа отчаяния',
#   'series_cnt': 37,
#   'films_cnt': 0},
#  '/suzumiya-haruhi/': {'ref': '/suzumiya-haruhi/',
#   'title': 'Меланхолия Харухи Судзумии',
#   'series_cnt': 44,
#   'films_cnt': 1},
#  '/black-bulet/': {'ref': '/black-bulet/',
#   'title': 'Черная пуля',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/nozaki-kun/': {'ref': '/nozaki-kun/',
#   'title': 'Ежемесячное сёдзё Нозаки-куна',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/plastic-memorie/': {'ref': '/plastic-memorie/',
#   'title': 'Синтетические воспоминания',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/wotaku-ni-koi/': {'ref': '/wotaku-ni-koi/',
#   'title': 'Так сложно любить отаку',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/kanojo-okarishimasu/': {'ref': '/kanojo-okarishimasu/',
#   'title': 'Девушка напрокат',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/baccano/': {'ref': '/baccano/',
#   'title': 'Шумиха!',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/ao-harou-ride/': {'ref': '/ao-harou-ride/',
#   'title': 'Дорога юности',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/kimi-ni-todoke/': {'ref': '/kimi-ni-todoke/',
#   'title': 'Дотянуться до тебя',
#   'series_cnt': 37,
#   'films_cnt': 0},
#  '/gotoubun-no-hanayome/': {'ref': '/gotoubun-no-hanayome/',
#   'title': 'Пять невест',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/saga-of-tanya/': {'ref': '/saga-of-tanya/',
#   'title': 'Военная хроника маленькой девочки',
#   'series_cnt': 12,
#   'films_cnt': 1},
#  '/mahoutsukai-no-yome/': {'ref': '/mahoutsukai-no-yome/',
#   'title': 'Невеста чародея',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/nichijou/': {'ref': '/nichijou/',
#   'title': 'Мелочи жизни',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/yuuri-on-ice/': {'ref': '/yuuri-on-ice/',
#   'title': 'Юри на льду',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/kami-tou/': {'ref': '/kami-tou/',
#   'title': 'Башня Бога',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/btoom/': {'ref': '/btoom/',
#   'title': 'Взрыв!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/kekai-sensen/': {'ref': '/kekai-sensen/',
#   'title': 'Стражи Барьера',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/gohs/': {'ref': '/gohs/',
#   'title': 'Царь горы',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/sono-bisque-doll/': {'ref': '/sono-bisque-doll/',
#   'title': 'Эта фарфоровая кукла влюбилась',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/koconnect/': {'ref': '/koconnect/',
#   'title': 'Связь сердец',
#   'series_cnt': 17,
#   'films_cnt': 0},
#  '/akatsuki-no-yona/': {'ref': '/akatsuki-no-yona/',
#   'title': 'Рассвет Йоны',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/masamune-kun-no-revenge/': {'ref': '/masamune-kun-no-revenge/',
#   'title': 'Месть Масамуне-куна!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/chainsaw-man/': {'ref': '/chainsaw-man/',
#   'title': 'Человек-бензопила',
#   'series_cnt': 4,
#   'films_cnt': 0},
#  '/beeastars/': {'ref': '/beeastars/',
#   'title': 'Выдающиеся звери',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/mushishi/': {'ref': '/mushishi/',
#   'title': 'Мастер муси',
#   'series_cnt': 47,
#   'films_cnt': 1},
#  '/majutsu-no-index/': {'ref': '/majutsu-no-index/',
#   'title': 'Индекс волшебства',
#   'series_cnt': 74,
#   'films_cnt': 1},
#  '/ookami-to-koshinryou/': {'ref': '/ookami-to-koshinryou/',
#   'title': 'Волчица и пряности',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/danshi-koukousei-no-nichijou/': {'ref': '/danshi-koukousei-no-nichijou/',
#   'title': 'Повседневная жизнь старшеклассников',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/higurashi-no-naku/': {'ref': '/higurashi-no-naku/',
#   'title': 'Когда плачут цикады',
#   'series_cnt': 116,
#   'films_cnt': 0},
#  '/banana-fish/': {'ref': '/banana-fish/',
#   'title': 'Банановая рыба',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/flcl/': {'ref': '/flcl/',
#   'title': 'Фури-кури',
#   'series_cnt': 12,
#   'films_cnt': 1},
#  '/onizuka/': {'ref': '/onizuka/',
#   'title': 'Крутой учитель Онидзука',
#   'series_cnt': 43,
#   'films_cnt': 0},
#  '/orange/': {'ref': '/orange/',
#   'title': 'Орендж',
#   'series_cnt': 13,
#   'films_cnt': 1},
#  '/free/': {'ref': '/free/',
#   'title': 'Вольный стиль!',
#   'series_cnt': 37,
#   'films_cnt': 1},
#  '/kabaneri/': {'ref': '/kabaneri/',
#   'title': 'Кабанери железной крепости',
#   'series_cnt': 12,
#   'films_cnt': 3},
#  '/gate/': {'ref': '/gate/',
#   'title': 'Врата: там бьются наши воины',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/inu-yasha/': {'ref': '/inu-yasha/',
#   'title': 'Инуяша',
#   'series_cnt': 241,
#   'films_cnt': 4},
#  '/shinsekai-youri/': {'ref': '/shinsekai-youri/',
#   'title': 'Из нового света',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/fumetsu-no-anata/': {'ref': '/fumetsu-no-anata/',
#   'title': 'Для тебя, Бессмертный',
#   'series_cnt': 22,
#   'films_cnt': 0},
#  '/yamada-kun/': {'ref': '/yamada-kun/',
#   'title': 'Ямада и семь ведьм',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/k-project/': {'ref': '/k-project/',
#   'title': 'Проект Кей',
#   'series_cnt': 26,
#   'films_cnt': 1},
#  '/komi-san-wa/': {'ref': '/komi-san-wa/',
#   'title': 'У Коми проблемы с общением',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/fruit-basket/': {'ref': '/fruit-basket/',
#   'title': 'Корзинка с фруктами',
#   'series_cnt': 63,
#   'films_cnt': 0},
#  '/sakamoto/': {'ref': '/sakamoto/',
#   'title': 'Я - Сакамото, а что?',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/kiznaaiver/': {'ref': '/kiznaaiver/',
#   'title': 'Связанные',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/trigun/': {'ref': '/trigun/',
#   'title': 'Триган',
#   'series_cnt': 26,
#   'films_cnt': 1},
#  '/nagatoro-san/': {'ref': '/nagatoro-san/',
#   'title': 'Не издевайся, Нагаторо',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/accel-world/': {'ref': '/accel-world/',
#   'title': 'Ускоренный мир',
#   'series_cnt': 26,
#   'films_cnt': 1},
#  '/grand-blue/': {'ref': '/grand-blue/',
#   'title': 'Необъятный океан',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/experiments-lain/': {'ref': '/experiments-lain/',
#   'title': 'Эксперименты Лэйн',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/grimgar/': {'ref': '/grimgar/',
#   'title': 'Гримгал пепла и иллюзий',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/hellsing/': {'ref': '/hellsing/',
#   'title': 'Хеллсинг: Война с нечистью',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/tsurezure-children/': {'ref': '/tsurezure-children/',
#   'title': 'Признания',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/wonderegg-priority/': {'ref': '/wonderegg-priority/',
#   'title': 'Приоритет чудо-яйца',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/domestic-kanojo/': {'ref': '/domestic-kanojo/',
#   'title': 'Домекано',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/gray-man/': {'ref': '/gray-man/',
#   'title': 'Ди Грэй-мен',
#   'series_cnt': 116,
#   'films_cnt': 0},
#  '/akashic-records/': {'ref': '/akashic-records/',
#   'title': 'Хроники Акаши',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/maou-gakuin/': {'ref': '/maou-gakuin/',
#   'title': 'Непризнанный школой владыка демонов!',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/kawaii-wake/': {'ref': '/kawaii-wake/',
#   'title': 'Ну не может моя сестрёнка быть такой милой',
#   'series_cnt': 32,
#   'films_cnt': 0},
#  '/91-days/': {'ref': '/91-days/',
#   'title': '91 день',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/bloodlad/': {'ref': '/bloodlad/',
#   'title': 'Кровавый парень',
#   'series_cnt': 10,
#   'films_cnt': 0},
#  '/umaaru-chan/': {'ref': '/umaaru-chan/',
#   'title': 'Двуличная сестрёнка Умару!',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/3-gatsu-no-lion/': {'ref': '/3-gatsu-no-lion/',
#   'title': 'Мартовский лев',
#   'series_cnt': 44,
#   'films_cnt': 0},
#  '/kuzu-honkai/': {'ref': '/kuzu-honkai/',
#   'title': 'Тайные желания отвергнутых',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/yuu-hakusho/': {'ref': '/yuu-hakusho/',
#   'title': 'Отчёт о буйстве духов',
#   'series_cnt': 112,
#   'films_cnt': 2},
#  '/tonikaku-kawaii/': {'ref': '/tonikaku-kawaii/',
#   'title': 'Унеси меня на Луну',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/ore-monougatari/': {'ref': '/ore-monougatari/',
#   'title': 'Моя история!',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/barakamon/': {'ref': '/barakamon/',
#   'title': 'Баракамон',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/luckystar/': {'ref': '/luckystar/',
#   'title': 'Счастливая звезда',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/shirayuki-hime/': {'ref': '/shirayuki-hime/',
#   'title': 'Красноволосая принцесса Белоснежка',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/blends/': {'ref': '/blends/',
#   'title': 'Садистская смесь',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/watashi-ga-motenai/': {'ref': '/watashi-ga-motenai/',
#   'title': 'Не моя вина, что я не популярна!',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/amagi-park/': {'ref': '/amagi-park/',
#   'title': 'Великолепный парк Амаги',
#   'series_cnt': 14,
#   'films_cnt': 0},
#  '/sukitte-ii-na-you/': {'ref': '/sukitte-ii-na-you/',
#   'title': 'Скажи: Я люблю тебя',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/baka-to-test/': {'ref': '/baka-to-test/',
#   'title': 'Дурни, тесты, аватары',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/gamers/': {'ref': '/gamers/',
#   'title': 'Геймеры!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/hataraku-sai-bou/': {'ref': '/hataraku-sai-bou/',
#   'title': 'Клетки за работой',
#   'series_cnt': 21,
#   'films_cnt': 0},
#  '/arifureta/': {'ref': '/arifureta/',
#   'title': 'Арифурэта: Сильнейший ремесленник в мире',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/satsuriku-no-tenshi/': {'ref': '/satsuriku-no-tenshi/',
#   'title': 'Ангел кровопролития',
#   'series_cnt': 16,
#   'films_cnt': 0},
#  '/eighty-six/': {'ref': '/eighty-six/',
#   'title': 'Восемьдесят шесть',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/ergo-proxy/': {'ref': '/ergo-proxy/',
#   'title': 'Эрго Прокси',
#   'series_cnt': 23,
#   'films_cnt': 0},
#  '/little-witch-academia/': {'ref': '/little-witch-academia/',
#   'title': 'Академия ведьмочек',
#   'series_cnt': 25,
#   'films_cnt': 1},
#  '/shiru-sekai/': {'ref': '/shiru-sekai/',
#   'title': 'Одному лишь Богу ведомый мир',
#   'series_cnt': 36,
#   'films_cnt': 0},
#  '/rokka-no-yuusha/': {'ref': '/rokka-no-yuusha/',
#   'title': 'Герои шестицветия',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/kamisama/': {'ref': '/kamisama/',
#   'title': 'Очень приятно - Бог',
#   'series_cnt': 31,
#   'films_cnt': 0},
#  '/bakuman/': {'ref': '/bakuman/',
#   'title': 'Бакуман',
#   'series_cnt': 75,
#   'films_cnt': 0},
#  '/pokemon/': {'ref': '/pokemon/',
#   'title': 'Покемон',
#   'series_cnt': 1176,
#   'films_cnt': 23},
#  '/inu-hero/': {'ref': '/inu-hero/',
#   'title': 'Инуяшики',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/vampire-knight/': {'ref': '/vampire-knight/',
#   'title': 'Рыцарь-вампир',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/great-pretender/': {'ref': '/great-pretender/',
#   'title': 'Великий притворщик',
#   'series_cnt': 23,
#   'films_cnt': 0},
#  '/to-aru-kagaku-no-railgun/': {'ref': '/to-aru-kagaku-no-railgun/',
#   'title': 'Некий научный Рейлган',
#   'series_cnt': 73,
#   'films_cnt': 0},
#  '/nagi-no-asu-kara/': {'ref': '/nagi-no-asu-kara/',
#   'title': 'Безоблачное завтра',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/berserk/': {'ref': '/berserk/',
#   'title': 'Берсерк',
#   'series_cnt': 54,
#   'films_cnt': 3},
#  '/zetsuen-tempest/': {'ref': '/zetsuen-tempest/',
#   'title': 'Буря потерь',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/sword-art-online-ggo/': {'ref': '/sword-art-online-ggo/',
#   'title': 'Мастера меча онлайн: альтернатива',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/beelzebub/': {'ref': '/beelzebub/',
#   'title': 'Вельзепуз',
#   'series_cnt': 60,
#   'films_cnt': 0},
#  '/shiki/': {'ref': '/shiki/',
#   'title': 'Усопшие',
#   'series_cnt': 22,
#   'films_cnt': 0},
#  '/ajins/': {'ref': '/ajins/',
#   'title': 'Полулюди',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/mondaiji-tachi/': {'ref': '/mondaiji-tachi/',
#   'title': 'Дети Индиго из другого мира',
#   'series_cnt': 10,
#   'films_cnt': 0},
#  '/lovely-complex/': {'ref': '/lovely-complex/',
#   'title': 'Трогательный комплекс',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/shinchou-yuusha/': {'ref': '/shinchou-yuusha/',
#   'title': 'Этот герой неуязвим, но очень осторожен',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/higashi-no-eden/': {'ref': '/higashi-no-eden/',
#   'title': 'Восточный Эдем',
#   'series_cnt': 11,
#   'films_cnt': 2},
#  '/karakai-jouzu/': {'ref': '/karakai-jouzu/',
#   'title': 'Поддразнивание Такаги',
#   'series_cnt': 37,
#   'films_cnt': 0},
#  '/gaangsta/': {'ref': '/gaangsta/',
#   'title': 'Гангста',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/katekyo-hitman-reborn/': {'ref': '/katekyo-hitman-reborn/',
#   'title': 'Учитель-мафиози Реборн',
#   'series_cnt': 203,
#   'films_cnt': 0},
#  '/katanagatari/': {'ref': '/katanagatari/',
#   'title': 'Истории мечей',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/hige-wo-soru/': {'ref': '/hige-wo-soru/',
#   'title': 'Я побрился. И приютил старшеклассницу',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/drifters/': {'ref': '/drifters/',
#   'title': 'Скитальцы',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/god-eatter/': {'ref': '/god-eatter/',
#   'title': 'Пожиратель богов',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/hanako-kun/': {'ref': '/hanako-kun/',
#   'title': 'Туалетный мальчик Ханако',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/shakugan-no-shana/': {'ref': '/shakugan-no-shana/',
#   'title': 'Жгучий взор Шаны',
#   'series_cnt': 73,
#   'films_cnt': 1},
#  '/oreshuura/': {'ref': '/oreshuura/',
#   'title': 'Меж двух огней',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/rebuild-of-evangelion/': {'ref': '/rebuild-of-evangelion/',
#   'title': 'Евангелион по-новому',
#   'series_cnt': 0,
#   'films_cnt': 3},
#  '/kenja-no-mago/': {'ref': '/kenja-no-mago/',
#   'title': 'Внук мудреца',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/gosick/': {'ref': '/gosick/',
#   'title': 'Готика',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/hajime-no-ippo/': {'ref': '/hajime-no-ippo/',
#   'title': 'Первый шаг',
#   'series_cnt': 127,
#   'films_cnt': 0},
#  '/musaigen-no-phantom-world/': {'ref': '/musaigen-no-phantom-world/',
#   'title': 'Мириады цветов фантомного мира',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/natsume-yujincho/': {'ref': '/natsume-yujincho/',
#   'title': 'Тетрадь дружбы Нацумэ',
#   'series_cnt': 74,
#   'films_cnt': 0},
#  '/tsuki-ga-kirei/': {'ref': '/tsuki-ga-kirei/',
#   'title': 'Прекрасна, как луна',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/aldnoah-zeroo/': {'ref': '/aldnoah-zeroo/',
#   'title': 'Альдноа Зеро',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/darw-game/': {'ref': '/darw-game/',
#   'title': 'Игра Дарвина',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/isekai-wa-smartphone/': {'ref': '/isekai-wa-smartphone/',
#   'title': 'В другом мире со смартфоном',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/ousama-ranking/': {'ref': '/ousama-ranking/',
#   'title': 'Рейтинг короля',
#   'series_cnt': 23,
#   'films_cnt': 0},
#  '/inu-x-boku/': {'ref': '/inu-x-boku/',
#   'title': 'Лис из секретной службы и я',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/sk8-infinity/': {'ref': '/sk8-infinity/',
#   'title': 'Скейт: Бесконечность',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/onmyouji/': {'ref': '/onmyouji/',
#   'title': 'Две звезды онмёджи',
#   'series_cnt': 50,
#   'films_cnt': 0},
#  '/megalobox/': {'ref': '/megalobox/',
#   'title': 'Мегалобокс',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/dorohedooro/': {'ref': '/dorohedooro/',
#   'title': 'Дорохедоро',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/full-metal-panic/': {'ref': '/full-metal-panic/',
#   'title': 'Стальная тревога',
#   'series_cnt': 61,
#   'films_cnt': 0},
#  '/usagi-drop/': {'ref': '/usagi-drop/',
#   'title': 'Брошенный кролик',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/hina-matsuri/': {'ref': '/hina-matsuri/',
#   'title': 'Праздник кукол',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/yakuindoomo/': {'ref': '/yakuindoomo/',
#   'title': 'Члены школьного совета',
#   'series_cnt': 26,
#   'films_cnt': 1},
#  '/rurouni-kenshi/': {'ref': '/rurouni-kenshi/',
#   'title': 'Бродяга Кэнсин',
#   'series_cnt': 95,
#   'films_cnt': 1},
#  '/tokyo-raven/': {'ref': '/tokyo-raven/',
#   'title': 'Токийские вороны',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/sora-yori-mo-tooi-basho/': {'ref': '/sora-yori-mo-tooi-basho/',
#   'title': 'Место за пределами вселенной',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/aho-girl/': {'ref': '/aho-girl/',
#   'title': 'Дурочка',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/vivy-fluorite-eye/': {'ref': '/vivy-fluorite-eye/',
#   'title': 'Виви: Песнь флюоритового глаза',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/death-march-kara/': {'ref': '/death-march-kara/',
#   'title': 'Марш смерти под рапсодию параллельного мира',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/re-creators/': {'ref': '/re-creators/',
#   'title': 'Возрождающие',
#   'series_cnt': 22,
#   'films_cnt': 0},
#  '/zombie-saga/': {'ref': '/zombie-saga/',
#   'title': 'Зомбиленд Сага',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/archenemy-hero/': {'ref': '/archenemy-hero/',
#   'title': 'Герой при заклятом враге',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/itai-no-wa/': {'ref': '/itai-no-wa/',
#   'title': 'Не люблю боль, вкачаю всё в защиту',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/fate-apocrypha/': {'ref': '/fate-apocrypha/',
#   'title': 'Судьба: Апокриф',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/ookami-shoujo/': {'ref': '/ookami-shoujo/',
#   'title': 'Волчица и чёрный принц',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/yuru-camp/': {'ref': '/yuru-camp/',
#   'title': 'Лагерь на свежем воздухе',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/kaze-no-stigma/': {'ref': '/kaze-no-stigma/',
#   'title': 'Печать ветра',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/takt-op-destiny/': {'ref': '/takt-op-destiny/',
#   'title': 'Такт Опус. Судьба',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/chihayfuru/': {'ref': '/chihayfuru/',
#   'title': 'Яркая Чихая',
#   'series_cnt': 74,
#   'films_cnt': 0},
#  '/gaabriel-dropout/': {'ref': '/gaabriel-dropout/',
#   'title': 'Габриэль бросает школу',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/mekakucity-actor/': {'ref': '/mekakucity-actor/',
#   'title': 'Актёры города Мекаку',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/vanitas-no-carte/': {'ref': '/vanitas-no-carte/',
#   'title': 'Мемуары Ванитаса',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/net-juu-no-susume/': {'ref': '/net-juu-no-susume/',
#   'title': 'Полноценная жизнь онлайн',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/love-live/': {'ref': '/love-live/',
#   'title': 'Живая любовь: проект школьный идол',
#   'series_cnt': 102,
#   'films_cnt': 1},
#  '/tanaka-kun/': {'ref': '/tanaka-kun/',
#   'title': 'Всегда вялый Танака-кун',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/dagashi-kashi/': {'ref': '/dagashi-kashi/',
#   'title': 'Магазинчик сладостей',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/asobi-asoba/': {'ref': '/asobi-asoba/',
#   'title': 'Давайте сыграем',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/hibike-euphonium/': {'ref': '/hibike-euphonium/',
#   'title': 'Звучи, эуфониум!',
#   'series_cnt': 26,
#   'films_cnt': 1},
#  '/eureka-seven/': {'ref': '/eureka-seven/',
#   'title': 'Эврика 7: Псалмы планет',
#   'series_cnt': 74,
#   'films_cnt': 1},
#  '/gakkougurashi/': {'ref': '/gakkougurashi/',
#   'title': 'Школьная жизнь!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/shiro-bako/': {'ref': '/shiro-bako/',
#   'title': 'Аниме от А до Я',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/watashi-ga-motete/': {'ref': '/watashi-ga-motete/',
#   'title': 'Мальчики, пожалуйста, целуйте его вместо меня',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/pandora-hearts/': {'ref': '/pandora-hearts/',
#   'title': 'Сердца Пандоры',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/saikou-no-ansatsusha/': {'ref': '/saikou-no-ansatsusha/',
#   'title': 'Лучший ассасин, переродившийся аристократом',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/houseki-no-kuni/': {'ref': '/houseki-no-kuni/',
#   'title': 'Страна самоцветов',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/no-6/': {'ref': '/no-6/',
#   'title': 'Шестая зона',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/shinwa-taikei/': {'ref': '/shinwa-taikei/',
#   'title': 'Сказ о четырёх с половиной татами',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/oresuki/': {'ref': '/oresuki/',
#   'title': 'Только ты любишь Великого Меня?',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/new-game/': {'ref': '/new-game/',
#   'title': 'Новая игра!',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/cardcaptor-sakura/': {'ref': '/cardcaptor-sakura/',
#   'title': 'Сакура - собирательница карт',
#   'series_cnt': 92,
#   'films_cnt': 2},
#  '/mieruko-chan/': {'ref': '/mieruko-chan/',
#   'title': 'Девочка, которая видит это',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/shiki-san/': {'ref': '/shiki-san/',
#   'title': 'Моя девушка не только милая',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/kara-no-kyoukai/': {'ref': '/kara-no-kyoukai/',
#   'title': 'Граница пустоты: Сад грешников',
#   'series_cnt': 0,
#   'films_cnt': 8},
#  '/iruma-kun/': {'ref': '/iruma-kun/',
#   'title': 'Добро пожаловать в ад, Ирума!',
#   'series_cnt': 48,
#   'films_cnt': 0},
#  '/nonnon-biyori/': {'ref': '/nonnon-biyori/',
#   'title': 'Деревенская глубинка',
#   'series_cnt': 38,
#   'films_cnt': 1},
#  '/bokutachi-wa-benkyou/': {'ref': '/bokutachi-wa-benkyou/',
#   'title': 'Мы не можем учиться!',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/darker-than-black/': {'ref': '/darker-than-black/',
#   'title': 'Темнее черного',
#   'series_cnt': 38,
#   'films_cnt': 0},
#  '/kyoko-suiri/': {'ref': '/kyoko-suiri/',
#   'title': 'Ложные выводы',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/inou-battle-wa-nichijou-kei/': {'ref': '/inou-battle-wa-nichijou-kei/',
#   'title': 'Супер бои в повседневности',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/otomes-game/': {'ref': '/otomes-game/',
#   'title': 'Моя реинкарнация в отомэ-игре в качестве главной злодейки',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/demi-chan/': {'ref': '/demi-chan/',
#   'title': 'Деми-тян хочет рассказать',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/tamakou-market/': {'ref': '/tamakou-market/',
#   'title': 'Лавочка Тамако',
#   'series_cnt': 12,
#   'films_cnt': 1},
#  '/yofukashi-no-uta/': {'ref': '/yofukashi-no-uta/',
#   'title': 'Песнь ночных сов',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/shingeki-no-bahamut/': {'ref': '/shingeki-no-bahamut/',
#   'title': 'Ярость Бахамута',
#   'series_cnt': 36,
#   'films_cnt': 0},
#  '/ore-no-nounai/': {'ref': '/ore-no-nounai/',
#   'title': 'Проклятие мультивыбора превратило мою жизнь в ад',
#   'series_cnt': 10,
#   'films_cnt': 0},
#  '/koi-uso/': {'ref': '/koi-uso/',
#   'title': 'Любовь и ложь',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/fugou-keiji/': {'ref': '/fugou-keiji/',
#   'title': 'Богатый детектив. Баланс: Неограничен',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/blue-period/': {'ref': '/blue-period/',
#   'title': 'Голубой период',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/worlds-trigger/': {'ref': '/worlds-trigger/',
#   'title': 'Импульс мира',
#   'series_cnt': 99,
#   'films_cnt': 0},
#  '/tasogare-otome/': {'ref': '/tasogare-otome/',
#   'title': 'Сумеречная дева и амнезия',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/koukaku-kidoutai/': {'ref': '/koukaku-kidoutai/',
#   'title': 'Призрак в доспехах: Синдром одиночки',
#   'series_cnt': 52,
#   'films_cnt': 0},
#  '/akudama-drive/': {'ref': '/akudama-drive/',
#   'title': 'Акудама Драйв',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/mikakunin/': {'ref': '/mikakunin/',
#   'title': 'Помолвлена с незнакомцем',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/rainbow/': {'ref': '/rainbow/',
#   'title': 'Радуга: Семеро из шестой камеры второго блока',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/d-frag/': {'ref': '/d-frag/',
#   'title': 'Адский Ад!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/ano-natsu/': {'ref': '/ano-natsu/',
#   'title': 'Мы ждём тебя летом',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/shumatsu-nani/': {'ref': '/shumatsu-nani/',
#   'title': 'Конец человечества',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/kawai-sou/': {'ref': '/kawai-sou/',
#   'title': 'Мы из общаги Кавай',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/kumo-desu-ga/': {'ref': '/kumo-desu-ga/',
#   'title': 'Да, я паук, и что?',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/hitsugi-chaika/': {'ref': '/hitsugi-chaika/',
#   'title': 'Гроб принцессы Чайки',
#   'series_cnt': 22,
#   'films_cnt': 0},
#  '/blood-plus/': {'ref': '/blood-plus/',
#   'title': 'Кровь+',
#   'series_cnt': 62,
#   'films_cnt': 2},
#  '/hidan-no-aria/': {'ref': '/hidan-no-aria/',
#   'title': 'Ария: Алая пуля',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/isekai-quartet/': {'ref': '/isekai-quartet/',
#   'title': 'Квартет из альтернативного мира',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/ping-pong/': {'ref': '/ping-pong/',
#   'title': 'Пинг-понг',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/sakamichi-no-apollo/': {'ref': '/sakamichi-no-apollo/',
#   'title': 'Аполлон: Дети на холме',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/arslan-senki/': {'ref': '/arslan-senki/',
#   'title': 'Сказание об Арслане',
#   'series_cnt': 33,
#   'films_cnt': 0},
#  '/amagamiss/': {'ref': '/amagamiss/',
#   'title': 'Лакомый кусочек',
#   'series_cnt': 51,
#   'films_cnt': 0},
#  '/bookofd/': {'ref': '/bookofd/',
#   'title': 'Тетрадь смерти',
#   'series_cnt': 37,
#   'films_cnt': 0},
#  '/specials-a/': {'ref': '/specials-a/',
#   'title': 'Спецкласс А',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/yuukoku-no-moriarty/': {'ref': '/yuukoku-no-moriarty/',
#   'title': 'Патриотизм Мориарти',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/busou-shoujo/': {'ref': '/busou-shoujo/',
#   'title': 'Тирания вооруженных девушек',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/shamanking/': {'ref': '/shamanking/',
#   'title': 'Шаман Кинг',
#   'series_cnt': 116,
#   'films_cnt': 0},
#  '/quan-zhi-gao-shou/': {'ref': '/quan-zhi-gao-shou/',
#   'title': 'Аватар короля',
#   'series_cnt': 27,
#   'films_cnt': 1},
#  '/majo-no-tabitabi/': {'ref': '/majo-no-tabitabi/',
#   'title': 'Путешествие Элейны',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/platinum-end/': {'ref': '/platinum-end/',
#   'title': 'Платиновый предел',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/rock-shooter/': {'ref': '/rock-shooter/',
#   'title': 'Стрелок с чёрной скалы',
#   'series_cnt': 20,
#   'films_cnt': 0},
#  '/jigoku-shojo/': {'ref': '/jigoku-shojo/',
#   'title': 'Адская девочка',
#   'series_cnt': 90,
#   'films_cnt': 0},
#  '/nyaruko-san/': {'ref': '/nyaruko-san/',
#   'title': 'Ползучий хаос Няруко-сан!',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/arakawa-bridge/': {'ref': '/arakawa-bridge/',
#   'title': 'Под мостом над Аракавой',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/out-break-company/': {'ref': '/out-break-company/',
#   'title': 'Мятежная компания',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/golden-kamuy/': {'ref': '/golden-kamuy/',
#   'title': 'Золотое божество',
#   'series_cnt': 41,
#   'films_cnt': 0},
#  '/space-dandy/': {'ref': '/space-dandy/',
#   'title': 'Космический Денди',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/sayonara-sensei/': {'ref': '/sayonara-sensei/',
#   'title': 'Прощай, унылый учитель',
#   'series_cnt': 38,
#   'films_cnt': 0},
#  '/gakkou-no-juliet/': {'ref': '/gakkou-no-juliet/',
#   'title': 'Джульетта из школы-интерната',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/bna/': {'ref': '/bna/',
#   'title': 'Совершенно новый зверь',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/initial-d/': {'ref': '/initial-d/',
#   'title': 'Инициал Ди',
#   'series_cnt': 81,
#   'films_cnt': 1},
#  '/kaiji/': {'ref': '/kaiji/',
#   'title': 'Кайдзи',
#   'series_cnt': 52,
#   'films_cnt': 0},
#  '/kemono-jihen/': {'ref': '/kemono-jihen/',
#   'title': 'Инцидент Кэмоно',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/diabolik-lover/': {'ref': '/diabolik-lover/',
#   'title': 'Дьявольские возлюбленные',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/yur-yur/': {'ref': '/yur-yur/',
#   'title': 'Лилии на ветру',
#   'series_cnt': 36,
#   'films_cnt': 0},
#  '/sewayaki-kitsune/': {'ref': '/sewayaki-kitsune/',
#   'title': 'Заботливая 800-летняя жена!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/suisei-no-gargantia/': {'ref': '/suisei-no-gargantia/',
#   'title': 'Гаргантия на просторах зелёной планеты',
#   'series_cnt': 15,
#   'films_cnt': 0},
#  '/b-the-beginning/': {'ref': '/b-the-beginning/',
#   'title': 'Би: Начало',
#   'series_cnt': 18,
#   'films_cnt': 0},
#  '/kotoura-san/': {'ref': '/kotoura-san/',
#   'title': 'Котоура-сан',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/tantei-wa-mou-shindeiru/': {'ref': '/tantei-wa-mou-shindeiru/',
#   'title': 'Детектив уже мёртв',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/id-invaded/': {'ref': '/id-invaded/',
#   'title': 'Вторжение. ID',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/combatants/': {'ref': '/combatants/',
#   'title': 'Комбатанты будут высланы!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/phantom-requiem/': {'ref': '/phantom-requiem/',
#   'title': 'Фантом: Реквием по Фантому',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/slime-taoshite-300-nen/': {'ref': '/slime-taoshite-300-nen/',
#   'title': 'Убивала слизней 300 лет до максимального уровня',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/hanasaku-iroha/': {'ref': '/hanasaku-iroha/',
#   'title': 'Азбука цветов',
#   'series_cnt': 26,
#   'films_cnt': 1},
#  '/beck/': {'ref': '/beck/', 'title': 'Бек', 'series_cnt': 26, 'films_cnt': 0},
#  '/school-rumble/': {'ref': '/school-rumble/',
#   'title': 'Школьный переполох',
#   'series_cnt': 52,
#   'films_cnt': 0},
#  '/shugi-yuusha-no-oukoku/': {'ref': '/shugi-yuusha-no-oukoku/',
#   'title': 'Герой-реалист перестраивает королевство',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/summertime/': {'ref': '/summertime/',
#   'title': 'Летнее время',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/michibiku-isekai/': {'ref': '/michibiku-isekai/',
#   'title': 'Лунное путешествие к новому миру',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/code-breaker/': {'ref': '/code-breaker/',
#   'title': 'Код: Крушитель',
#   'series_cnt': 16,
#   'films_cnt': 0},
#  '/seto-hanayome/': {'ref': '/seto-hanayome/',
#   'title': 'Морская невеста',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/wolfs-rain/': {'ref': '/wolfs-rain/',
#   'title': 'Волчий дождь',
#   'series_cnt': 30,
#   'films_cnt': 0},
#  '/ben-to/': {'ref': '/ben-to/',
#   'title': 'Бэнто',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/assassin-pride/': {'ref': '/assassin-pride/',
#   'title': 'Гордость убийцы',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/tales-of-zestiria/': {'ref': '/tales-of-zestiria/',
#   'title': 'Сказания Зестирии',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/azumanga-daioh/': {'ref': '/azumanga-daioh/',
#   'title': 'Адзуманга Дайо',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/witch-works/': {'ref': '/witch-works/',
#   'title': 'Ведьмина магия в деле',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/tomozaki-kun/': {'ref': '/tomozaki-kun/',
#   'title': 'Низкоуровневый персонаж Томодзаки',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/reeal-girl/': {'ref': '/reeal-girl/',
#   'title': 'Реальная девушка',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/nan-baka/': {'ref': '/nan-baka/',
#   'title': 'Намбака',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/eizouken/': {'ref': '/eizouken/',
#   'title': 'Руки прочь от киноклуба!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/shoujo-shuumatsu/': {'ref': '/shoujo-shuumatsu/',
#   'title': 'Девушки в последнем путешествии',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/irozuku-sekai/': {'ref': '/irozuku-sekai/',
#   'title': 'Из завтрашнего дня разноцветного мира',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/rikekoi/': {'ref': '/rikekoi/',
#   'title': 'Наука влюблена, и мы докажем это',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/carole-and-tuesday/': {'ref': '/carole-and-tuesday/',
#   'title': 'Кэрол и Тьюсдей',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/ballroom/': {'ref': '/ballroom/',
#   'title': 'Сквозь бальный зал',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/achi-kochi/': {'ref': '/achi-kochi/',
#   'title': 'С места на место',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/araburu-kisetsu/': {'ref': '/araburu-kisetsu/',
#   'title': 'Девичье сезонное обострение',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/kakushigoto/': {'ref': '/kakushigoto/',
#   'title': 'Скрытые вещи',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/nodame-cantabile/': {'ref': '/nodame-cantabile/',
#   'title': 'Нодамэ Кантабиле',
#   'series_cnt': 45,
#   'films_cnt': 0},
#  '/xxxholic/': {'ref': '/xxxholic/',
#   'title': 'Триплексоголик',
#   'series_cnt': 37,
#   'films_cnt': 1},
#  '/tenkyou-no-alderamin/': {'ref': '/tenkyou-no-alderamin/',
#   'title': 'Альдерамин в небе',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/isshuukan-friends/': {'ref': '/isshuukan-friends/',
#   'title': 'Друзья на неделю',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/gakuen-babysitters/': {'ref': '/gakuen-babysitters/',
#   'title': 'Школьные няни',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/lycoreco/': {'ref': '/lycoreco/',
#   'title': 'Ликорис Рикойл',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/devil-may-cry/': {'ref': '/devil-may-cry/',
#   'title': 'Дьявол может плакать',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/amaama-to-inazuma/': {'ref': '/amaama-to-inazuma/',
#   'title': 'Дуэт и вспышка молнии',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/control/': {'ref': '/control/',
#   'title': 'Контроль',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/denpa-onna/': {'ref': '/denpa-onna/',
#   'title': 'Радиосигнал от чудачки. Юноша на связи',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/hamatora-anima/': {'ref': '/hamatora-anima/',
#   'title': 'Детективное агентство Хаматора',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/seiken-tsukai/': {'ref': '/seiken-tsukai/',
#   'title': 'Святая троица: мечи, магия, школа',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/air/': {'ref': '/air/', 'title': 'Высь', 'series_cnt': 12, 'films_cnt': 1},
#  '/soredemo-sekai-utsukushii/': {'ref': '/soredemo-sekai-utsukushii/',
#   'title': 'Мир по-прежнему красив',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/bokurema/': {'ref': '/bokurema/',
#   'title': 'Ремейк нашей жизни',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/dimension-wa/': {'ref': '/dimension-wa/',
#   'title': 'Измерение W',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/munou-na-nana/': {'ref': '/munou-na-nana/',
#   'title': 'Бездарная Нана',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/mawaru-penguindram/': {'ref': '/mawaru-penguindram/',
#   'title': 'Пингвиний барабан',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/tensura-nikki/': {'ref': '/tensura-nikki/',
#   'title': 'Дневник слизи-попаданца',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/deshi-kenichi/': {'ref': '/deshi-kenichi/',
#   'title': 'Сильнейший в истории ученик Кеничи',
#   'series_cnt': 50,
#   'films_cnt': 0},
#  '/nazo-no-kanojo/': {'ref': '/nazo-no-kanojo/',
#   'title': 'Загадочная девушка Х',
#   'series_cnt': 14,
#   'films_cnt': 0},
#  '/yesterday/': {'ref': '/yesterday/',
#   'title': 'Спой для меня Вчера',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/amnesia/': {'ref': '/amnesia/',
#   'title': 'Амнезия',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/seirei-gensouki/': {'ref': '/seirei-gensouki/',
#   'title': 'Мифический дух: Хроники',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/yuusha-no-densetsu/': {'ref': '/yuusha-no-densetsu/',
#   'title': 'Легенда о легендарных героях',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/magnitude/': {'ref': '/magnitude/',
#   'title': 'Токийское восьмибалльное',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/grancrest-senky/': {'ref': '/grancrest-senky/',
#   'title': 'Легенда о Гранкресте',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/cheat-magician/': {'ref': '/cheat-magician/',
#   'title': 'Маг-обманщик из другого мира',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/oda-nobuna/': {'ref': '/oda-nobuna/',
#   'title': 'Великие помыслы Оды Нобуны',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/kono-bijutsubu/': {'ref': '/kono-bijutsubu/',
#   'title': 'С этим клубом точно что-то не так!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/just-cause/': {'ref': '/just-cause/',
#   'title': 'Да просто так!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/chaos-head/': {'ref': '/chaos-head/',
#   'title': 'Хаос. Вершина',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/girls-and-panzer/': {'ref': '/girls-and-panzer/',
#   'title': 'Девушки и танки',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/little-buster/': {'ref': '/little-buster/',
#   'title': 'Маленькие проказники!',
#   'series_cnt': 39,
#   'films_cnt': 0},
#  '/decadence/': {'ref': '/decadence/',
#   'title': 'Дека-данс',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/gin-saji/': {'ref': '/gin-saji/',
#   'title': 'Серебряная ложка',
#   'series_cnt': 22,
#   'films_cnt': 0},
#  '/shouwa-genroku/': {'ref': '/shouwa-genroku/',
#   'title': 'Сквозь эпохи: Узы ракуго',
#   'series_cnt': 25,
#   'films_cnt': 0},
#  '/koi-wa-ameagari/': {'ref': '/koi-wa-ameagari/',
#   'title': 'Любовь похожа на прошедший дождь',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/kanata-no-astra/': {'ref': '/kanata-no-astra/',
#   'title': 'Астра, затерянная в космосе',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/kaze-tsuyoku-fuiteiru/': {'ref': '/kaze-tsuyoku-fuiteiru/',
#   'title': 'Почувствуй ветер',
#   'series_cnt': 23,
#   'films_cnt': 0},
#  '/gridman/': {'ref': '/gridman/',
#   'title': 'Гридмен',
#   'series_cnt': 12,
#   'films_cnt': 0},
# ...
#   'title': 'Джибиэйт',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/kai-byoui-ramune/': {'ref': '/kai-byoui-ramune/',
#   'title': 'Доктор Рамунэ - специалист по таинственным болезням',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/dragon-quest/': {'ref': '/dragon-quest/',
#   'title': 'Драгон Квест: Приключения Дая',
#   'series_cnt': 100,
#   'films_cnt': 0},
#  '/shoumetsu-toshi/': {'ref': '/shoumetsu-toshi/',
#   'title': 'Исчезнувший город',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/kanon/': {'ref': '/kanon/',
#   'title': 'Канон',
#   'series_cnt': 37,
#   'films_cnt': 0},
#  '/majutsushi-orphen/': {'ref': '/majutsushi-orphen/',
#   'title': 'Волшебник-воин Орфен',
#   'series_cnt': 72,
#   'films_cnt': 0},
#  '/kings-raid/': {'ref': '/kings-raid/',
#   'title': 'Королевский рейд: Наследники воли',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/kodomo-no-omocha/': {'ref': '/kodomo-no-omocha/',
#   'title': 'Детская игрушка',
#   'series_cnt': 102,
#   'films_cnt': 0},
#  '/mayonaka-no-occult/': {'ref': '/mayonaka-no-occult/',
#   'title': 'Оккультные служащие полуночи',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/richard-shi/': {'ref': '/richard-shi/',
#   'title': 'Дело ювелира Ричарда',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/revisions/': {'ref': '/revisions/',
#   'title': 'Ревижены',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/idolish7/': {'ref': '/idolish7/',
#   'title': 'Семёрка идолов',
#   'series_cnt': 45,
#   'films_cnt': 0},
#  '/ramen-daisuki-koizumi/': {'ref': '/ramen-daisuki-koizumi/',
#   'title': 'Коидзуми любит рамен',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/listeners/': {'ref': '/listeners/',
#   'title': 'Слушатели',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/kanren-no-skill/': {'ref': '/kanren-no-skill/',
#   'title': 'Стал сильнейшим, прокачивая фермерство',
#   'series_cnt': 5,
#   'films_cnt': 0},
#  '/akiba-maid/': {'ref': '/akiba-maid/',
#   'title': 'Война горничных Акибы',
#   'series_cnt': 5,
#   'films_cnt': 0},
#  '/do-it-yourself/': {'ref': '/do-it-yourself/',
#   'title': 'Сделай это сам!',
#   'series_cnt': 5,
#   'films_cnt': 0},
#  '/idoly-pride/': {'ref': '/idoly-pride/',
#   'title': 'Расцвет идолов',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/houkago-teibou/': {'ref': '/houkago-teibou/',
#   'title': 'Рыбалка для школьниц после занятий',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/planet-with/': {'ref': '/planet-with/',
#   'title': 'Планета Уит',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/tokyo-24-ku/': {'ref': '/tokyo-24-ku/',
#   'title': '24-й округ Токио',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/hypnosis-mic/': {'ref': '/hypnosis-mic/',
#   'title': 'Гипнотический микрофон: Рэп-баттл дивизионов',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/boku-no-tonari/': {'ref': '/boku-no-tonari/',
#   'title': 'Мой сосед - бог разрушения!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/18if/': {'ref': '/18if/',
#   'title': 'Измерение 18',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/hortensia-saga/': {'ref': '/hortensia-saga/',
#   'title': 'Сага о Гортензии',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/koi-to-producer/': {'ref': '/koi-to-producer/',
#   'title': 'Любовь и продюсер',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/taisou-zamurai/': {'ref': '/taisou-zamurai/',
#   'title': 'Самурай-гимнаст',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/hero-tarumono/': {'ref': '/hero-tarumono/',
#   'title': 'Стать настоящей героиней!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/saredo-tsumibito-wa-ryuu-to-odoru/': {'ref': '/saredo-tsumibito-wa-ryuu-to-odoru/',
#   'title': 'И всё же, грешник танцует с драконом',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/vampire-garden/': {'ref': '/vampire-garden/',
#   'title': 'Вампир в саду',
#   'series_cnt': 5,
#   'films_cnt': 0},
#  '/baraou-no-souretsu/': {'ref': '/baraou-no-souretsu/',
#   'title': 'Реквием по Королю Роз',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/dragon-ie-wo-kau/': {'ref': '/dragon-ie-wo-kau/',
#   'title': 'Дракон в поисках дома',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/slow-loop/': {'ref': '/slow-loop/',
#   'title': 'Медленная петля',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/seven-knights-revolution/': {'ref': '/seven-knights-revolution/',
#   'title': 'Революция семи рыцарей: Наследники героев',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/granbelm/': {'ref': '/granbelm/',
#   'title': 'Гранбелм',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/muhyo-to-rouji/': {'ref': '/muhyo-to-rouji/',
#   'title': 'Бюро паранормальных расследований Мухё и Роджи',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/kunoichi-tsubaki/': {'ref': '/kunoichi-tsubaki/',
#   'title': 'В сердце куноичи Цубаки',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/bungou-to-alchemist/': {'ref': '/bungou-to-alchemist/',
#   'title': 'Литераторы и алхимики: Шестерни судей',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/fuuto-tantei/': {'ref': '/fuuto-tantei/',
#   'title': 'Детективы Футо',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/kuroitsu-san/': {'ref': '/kuroitsu-san/',
#   'title': 'Куроицу из отдела сверхчеловеческого развития',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/romeo-no-aoi/': {'ref': '/romeo-no-aoi/',
#   'title': 'Голубые небеса Ромео',
#   'series_cnt': 33,
#   'films_cnt': 0},
#  '/saikoro-club/': {'ref': '/saikoro-club/',
#   'title': 'Клуб настольных игр',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/renai-flops/': {'ref': '/renai-flops/',
#   'title': 'Любовные неудачи',
#   'series_cnt': 3,
#   'films_cnt': 0},
#  '/hakozume-kouban/': {'ref': '/hakozume-kouban/',
#   'title': 'Контратака женщины-полицейского',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/vatican-kiseki-chousakan/': {'ref': '/vatican-kiseki-chousakan/',
#   'title': 'Инспекторы чудес Ватикана',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/mirai-shounen-conan/': {'ref': '/mirai-shounen-conan/',
#   'title': 'Конан - мальчик из будущего',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/keishichou/': {'ref': '/keishichou/',
#   'title': 'Специальный отдел криминальных расследований: Токунана',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/phantom-in-the-twilight/': {'ref': '/phantom-in-the-twilight/',
#   'title': 'Фантом в сумерках',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/koukyuu-no-karasu/': {'ref': '/koukyuu-no-karasu/',
#   'title': 'Ворона в гареме',
#   'series_cnt': 5,
#   'films_cnt': 0},
#  '/kono-healer/': {'ref': '/kono-healer/',
#   'title': 'Этот противный целитель!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/gekihatsu-boy/': {'ref': '/gekihatsu-boy/',
#   'title': 'Сумасшедшие ребята',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/starmyu/': {'ref': '/starmyu/',
#   'title': 'Музыкальная школа звёзд',
#   'series_cnt': 36,
#   'films_cnt': 0},
#  '/lost-song/': {'ref': '/lost-song/',
#   'title': 'Потерянная песня',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/dolls-frontline/': {'ref': '/dolls-frontline/',
#   'title': 'Девушки на линии фронта',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/ensemble-stars/': {'ref': '/ensemble-stars/',
#   'title': 'Звёзды ансамбля!',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/hoshi-no-samidare/': {'ref': '/hoshi-no-samidare/',
#   'title': 'Люцифер и Бисквитный Молот',
#   'series_cnt': 16,
#   'films_cnt': 0},
#  '/yakunara-mug/': {'ref': '/yakunara-mug/',
#   'title': 'Давайте тоже слепим кружку',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/22-7/': {'ref': '/22-7/',
#   'title': '22 на 7',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/senyoku-no-sigrdrifa/': {'ref': '/senyoku-no-sigrdrifa/',
#   'title': 'Полководцы Сигрдрифа',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/night-head/': {'ref': '/night-head/',
#   'title': 'Сумеречный разум',
#   'series_cnt': 36,
#   'films_cnt': 0},
#  '/lapis-re-lights/': {'ref': '/lapis-re-lights/',
#   'title': 'Лазурные огни',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/anima-yell/': {'ref': '/anima-yell/',
#   'title': 'Девичьи кричалки!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/watashi-no-cramer/': {'ref': '/watashi-no-cramer/',
#   'title': 'Прощай, мой дорогой Крамер',
#   'series_cnt': 13,
#   'films_cnt': 1},
#  '/zx-ignition/': {'ref': '/zx-ignition/',
#   'title': 'Зет Икс: Зажигание',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/budoukan/': {'ref': '/budoukan/',
#   'title': 'Будокан скажет вам, когда я умру',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/rerided/': {'ref': '/rerided/',
#   'title': 'Деррида, покоривший время. RErideD',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/deep-insanity/': {'ref': '/deep-insanity/',
#   'title': 'Безумное погружение: Потерянное дитя',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/tribe-nine/': {'ref': '/tribe-nine/',
#   'title': 'Клан девяти',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/chuukan-kanriroku-tonegawa/': {'ref': '/chuukan-kanriroku-tonegawa/',
#   'title': 'Менеджер среднего звена Тонэгава',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/mushikaburi-hime/': {'ref': '/mushikaburi-hime/',
#   'title': 'Принцесса-библиофил',
#   'series_cnt': 4,
#   'films_cnt': 0},
#  '/selection-project/': {'ref': '/selection-project/',
#   'title': 'Отбор проектов',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/leading-stars/': {'ref': '/leading-stars/',
#   'title': 'Ведущие звёзды',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/birdie-wing/': {'ref': '/birdie-wing/',
#   'title': 'Птичье крыло: История гольфисток',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/juushinki-pandora/': {'ref': '/juushinki-pandora/',
#   'title': 'Небесная машина Пандора',
#   'series_cnt': 26,
#   'films_cnt': 0},
#  '/glass-no-kamen/': {'ref': '/glass-no-kamen/',
#   'title': 'Стеклянная маска',
#   'series_cnt': 51,
#   'films_cnt': 0},
#  '/back-arrow/': {'ref': '/back-arrow/',
#   'title': 'Путь назад',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/shachou-battle/': {'ref': '/shachou-battle/',
#   'title': 'Президент, пришло время для битвы!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/ochifuru/': {'ref': '/ochifuru/',
#   'title': 'Фруктовый пирог: Айдолы-неудачницы',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/rifle-beautiful/': {'ref': '/rifle-beautiful/',
#   'title': 'Винтовка прекрасна',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/double-decker/': {'ref': '/double-decker/',
#   'title': 'Двойной удар: Даг и Кирилл',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/visual-prison/': {'ref': '/visual-prison/',
#   'title': 'Визуальная тюрьма',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/magatsu-wahrheit/': {'ref': '/magatsu-wahrheit/',
#   'title': 'Бедственная правда',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/muv-luv/': {'ref': '/muv-luv/',
#   'title': 'Мав-Лав: Альтернатива',
#   'series_cnt': 53,
#   'films_cnt': 0},
#  '/love-all-play/': {'ref': '/love-all-play/',
#   'title': 'Игра с нулевым счётом',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/robihachi/': {'ref': '/robihachi/',
#   'title': 'РобиХати',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/spring-and-summer/': {'ref': '/spring-and-summer/',
#   'title': 'А3! Весна и лето',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/major-2nd/': {'ref': '/major-2nd/',
#   'title': 'Второй Мэйджор',
#   'series_cnt': 50,
#   'films_cnt': 0},
#  '/shinmai-renkin/': {'ref': '/shinmai-renkin/',
#   'title': 'Магазинчик начинающего алхимика',
#   'series_cnt': 5,
#   'films_cnt': 0},
#  '/project-scard/': {'ref': '/project-scard/',
#   'title': 'Проект Скард: Шрам Прэйтер',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/tamayomi/': {'ref': '/tamayomi/',
#   'title': 'Тамаёми',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/merc-storia/': {'ref': '/merc-storia/',
#   'title': 'История Мерк',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/futsal-boys/': {'ref': '/futsal-boys/',
#   'title': 'Мини-футбол для мальчиков',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/nobunaga/': {'ref': '/nobunaga/',
#   'title': 'Прекрасная бабочка: Юный Нобунага',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/bucchigire/': {'ref': '/bucchigire/',
#   'title': 'Буччигирэ!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/hachigatsu-no-cinderella/': {'ref': '/hachigatsu-no-cinderella/',
#   'title': 'Девять золушек в августе',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/healer-girl/': {'ref': '/healer-girl/',
#   'title': 'Девушка-целитель',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/kitsutsuki/': {'ref': '/kitsutsuki/',
#   'title': 'Детективное агентство дятла',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/ginga-nagareboshi/': {'ref': '/ginga-nagareboshi/',
#   'title': 'Серебряный клык',
#   'series_cnt': 47,
#   'films_cnt': 0},
#  '/wz/': {'ref': '/wz/', 'title': 'Уиз', 'series_cnt': 13, 'films_cnt': 0},
#  '/stand-my-heroes/': {'ref': '/stand-my-heroes/',
#   'title': 'За мной, мои герои: часть истины',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/saku-ra-taisen/': {'ref': '/saku-ra-taisen/',
#   'title': 'Войны Сакуры',
#   'series_cnt': 37,
#   'films_cnt': 1},
#  '/pride-of-orange/': {'ref': '/pride-of-orange/',
#   'title': 'Гордость оранжевых!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/bakumatsu/': {'ref': '/bakumatsu/',
#   'title': 'Парень из эпохи Бакумацу',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/cue-idol/': {'ref': '/cue-idol/',
#   'title': 'Титры!',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/gokinjo-monogatari/': {'ref': '/gokinjo-monogatari/',
#   'title': 'Повесть о соседях',
#   'series_cnt': 62,
#   'films_cnt': 1},
#  '/uchi-tama/': {'ref': '/uchi-tama/',
#   'title': 'Тама: откуда же он взялся?',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/arsnotoria/': {'ref': '/arsnotoria/',
#   'title': 'Солнечная улыбка Арснотории!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/mix-meisei-story/': {'ref': '/mix-meisei-story/',
#   'title': 'Микс: История Мэйсэй',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/prima-doll/': {'ref': '/prima-doll/',
#   'title': 'Прима-кукла',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/hakyuu-houshin-engi/': {'ref': '/hakyuu-houshin-engi/',
#   'title': 'Охотник за душами',
#   'series_cnt': 23,
#   'films_cnt': 0},
#  '/oda-cinnamon/': {'ref': '/oda-cinnamon/',
#   'title': 'Ода Корица Нобунага',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/c-danchi/': {'ref': '/c-danchi/',
#   'title': 'Жилой комплекс Си',
#   'series_cnt': 4,
#   'films_cnt': 0},
#  '/4-nin-wa-sorezore/': {'ref': '/4-nin-wa-sorezore/',
#   'title': 'Четыре человека и ложь каждого',
#   'series_cnt': 3,
#   'films_cnt': 0},
#  '/cestvs/': {'ref': '/cestvs/',
#   'title': 'Цестус: Римский боец',
#   'series_cnt': 11,
#   'films_cnt': 0},
#  '/try-knight/': {'ref': '/try-knight/',
#   'title': 'Рыцари усердия',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/gensou-sangokushi/': {'ref': '/gensou-sangokushi/',
#   'title': 'Фантазия о Троецарствии: Духовность небес',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/actors/': {'ref': '/actors/',
#   'title': 'Артисты: конкурс песен',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/aoki-kagayaki/': {'ref': '/aoki-kagayaki/',
#   'title': 'Меч Жёлтого императора: Бледное сияние',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/uchi-no-shishou/': {'ref': '/uchi-no-shishou/',
#   'title': 'У моего мастера нет хвоста',
#   'series_cnt': 5,
#   'films_cnt': 0},
#  '/i-chu-halfway/': {'ref': '/i-chu-halfway/',
#   'title': 'АйТю: Звёздная сцена',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/gekidol/': {'ref': '/gekidol/',
#   'title': 'Гэкидол',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/namu-amida-butsu/': {'ref': '/namu-amida-butsu/',
#   'title': 'Да здравствует Амитабха: Лотус Утены',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/shadow-verse/': {'ref': '/shadow-verse/',
#   'title': 'Поэзия теней',
#   'series_cnt': 78,
#   'films_cnt': 0},
#  '/soukou-musume/': {'ref': '/soukou-musume/',
#   'title': 'Девушки в доспехах',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/seiken-densetsu/': {'ref': '/seiken-densetsu/',
#   'title': 'Легенда о святом мече: Легенда маны',
#   'series_cnt': 4,
#   'films_cnt': 0},
#  '/shin-chuuka/': {'ref': '/shin-chuuka/',
#   'title': 'Новый мастер кулинарии',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/maesetsu/': {'ref': '/maesetsu/',
#   'title': 'Разминка!',
#   'series_cnt': 12,
#   'films_cnt': 0},
#  '/yi-nian-yong-heng/': {'ref': '/yi-nian-yong-heng/',
#   'title': 'Вечная воля',
#   'series_cnt': 70,
#   'films_cnt': 0},
#  '/argonavis/': {'ref': '/argonavis/',
#   'title': 'Аргонавис из Ура мечте!',
#   'series_cnt': 13,
#   'films_cnt': 0},
#  '/bai-yao-pu/': {'ref': '/bai-yao-pu/',
#   'title': 'Руководство сотен демонов',
#   'series_cnt': 24,
#   'films_cnt': 0},
#  '/extreme-hearts/': {'ref': '/extreme-hearts/',
#   'title': 'Экстремальные сердца',
#   'series_cnt': 12,
#   'films_cnt': 0}}

# %%
# for key in selected:
#     response = requests.get(f"https://jut.su{key}",
#                        headers = {
#         'User-Agent': user_agent
#     })
#     content = response.content.decode('cp1251').encode('utf8')
#     series = Selector(text=response.content).xpath('//a[contains(@class, "short-btn")]//@href')
#     diff = len(series) - anime_dict[key]["n_series"]
#     if  diff!= 0:
#         name = anime_dict[key]["name"]
#         print(f"{name} {diff} новых серий!")
#     anime_dict[key]["n_series"] = len(series)
# # TODO descrpition
# # x.xpath('.//div[contains(@class, "tooltip_of_the_anime")]/@content').get()

# %%
# class AnimeObserver():
#     def __init__(self, selected):
#         self.selected = selected

# %%
selected_item = selected_dict['/full-metal-alchemist/']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6880/198661145.py in <module>
# ----> 1 selected_item = selected_dict['/full-metal-alchemist/']
#
# NameError: name 'selected_dict' is not defined

# %%
# from telegram.ext.updater import Updater
# from telegram.update import Update
# from telegram.ext.callbackcontext import CallbackContext
# from telegram.ext.commandhandler import CommandHandler
# from telegram.ext.messagehandler import MessageHandler
# from telegram.ext.filters import Filters
#
# updater = Updater("token", use_context=True)
#
#
# def start(update: Update, context: CallbackContext):
#     update.message.reply_text(
#         "Hello sir, Welcome to the Bot.Please write\
#         /help to see the commands available.")
#
# def help(update: Update, context: CallbackContext):
#     update.message.reply_text("""Available Commands :-
#     /add - Add selected series
#     /remove - Remove series from selected list
#     """)
#
#
# def add(update: Update, context: CallbackContext):
#     update.message.reply_text(
#         f"{selected_item['name']}: {selected_item['series_cnt']}")
#
# def remove(update: Update, context: CallbackContext):
#     update.message.reply_text(
#         "Remove items")
#
#
#
#
#
# def unknown(update: Update, context: CallbackContext):
#     update.message.reply_text(
#         "Sorry '%s' is not a valid command" % update.message.text)
#
#
# def unknown_text(update: Update, context: CallbackContext):
#     update.message.reply_text(
#         "Sorry I can't recognize you , you said '%s'" % update.message.text)
#
#
# updater.dispatcher.add_handler(CommandHandler('start', start))
# updater.dispatcher.add_handler(CommandHandler('add', add))
# updater.dispatcher.add_handler(CommandHandler('remove', remove))
# updater.dispatcher.add_handler(CommandHandler('help', help))
# updater.dispatcher.add_handler(MessageHandler(Filters.text, unknown))
# updater.dispatcher.add_handler(MessageHandler(
#     Filters.command, unknown)) # Filters out unknown commands
#
# # Filters out unknown messages.
# updater.dispatcher.add_handler(MessageHandler(Filters.text, unknown_text))
#
# updater.start_polling()
